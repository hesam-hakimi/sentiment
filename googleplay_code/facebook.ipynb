# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
import time
import datetime
import io
import sqlite3

# %%
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")
driver = webdriver.Chrome(chrome_options=options)
# Out:
# <ipython-input-16-b5f1867c00b1>:3: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options=options)

# %%
driver.get("https://www.google.com")

# %%
button=driver.find_element_by_xpath("//input")

# %%
button.send_keys("google play facebook")

# %%
button.send_keys(Keys.RETURN)

# %%
#serach for the applcation in the Google play
try:
    link=WebDriverWait(driver,10).until(
        expected_conditions.presence_of_all_elements_located(
            (By.PARTIAL_LINK_TEXT, "Facebook – Apps on Google Play")
        )                
    )
    link[0].click()
except Exception as e:
    print(e)

# %%
#click on the read all revies for the first time in the page
try:
    read_all_reviews=WebDriverWait(driver, 4).until(
        expected_conditions.presence_of_element_located((By.XPATH, '//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[6]/div/span/span'))
    )  
except Exception as e:
    print(e)
read_all_reviews.click()
#//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[6]/div/span/span

# %%
def create_table_pintrest():
    conn = sqlite3.connect(database='hesam.db')
    cur = conn.cursor()
    cur.execute(
        # 'comment', 'author', 'rate', 'cr_date','likes'
        'CREATE TABLE IF NOT EXISTS [Facebook]  (comment text,author text, rate int,cr_date text, likes int  )')
    conn.commit()
    conn.close()
# insert

def insert(comment ,author , rate ,cr_date , likes):
    conn = sqlite3.connect(database='hesam.db')
    cur = conn.cursor()
    cur.execute("insert into Facebook values(?,?,?,?,?)", (comment ,author , rate ,cr_date , likes ))
    conn.commit()
    conn.close()
    
def select():
    conn = sqlite3.connect('hesam.db')
    cur = conn.cursor()
    cur.execute('select * from Facebook')
    t1 = cur.fetchall()
    conn.close()
    return t1

def delete():
    conn = sqlite3.connect('hesam.db')
    cur = conn.cursor()
    cur.execute("delete from Facebook ")
    conn.commit()
    conn.close()

# %%
create_table_pintrest()

# %%
delete()

# %%
def ful_reviws(i):
    result ='ful_reviws'
    try:
        
        ful_reviws=driver.find_element_by_xpath(
            F'//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[{i}]/div/div[2]/div[2]/span[1]/div/button'
            )
        ful_reviws.click()

    except :
        pass

def get_comments(i):
    result='get_comments'
     
    try:
        result= driver.find_elements_by_xpath(
                F'//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[{i}]/div/div[2]/div[2]/span'
                )
        result=''.join ([x.text for x in result ])
        
    except Exception as e:
        print(e) 
    return result

def get_author(i):
    result='get_author'
    try:
        result= driver.find_element_by_xpath(
            f'//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[{i}]/div/div[2]/div[1]/div[1]/span'
        ).text
    except Exception as e:
        print(e) 
    return result 

def get_rating(i):
    result='get_rating'
    try:
        rating=driver.find_element_by_xpath(
            f'//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[{i}]/div/div[2]/div[1]/div[1]/div/span[1]/div/div'
        ).get_attribute("aria-label")
        result =rating [6:7]
    except Exception as e:
        print(e) 
    return result 

def get_date(i):
    result='get_date'
    try:
        date=driver.find_element_by_xpath(
            f'//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[{i}]/div/div[2]/div[1]/div[1]/div/span[2]'
        ).text
        result=  datetime.datetime.strptime( date.replace(',',''), '%B %d %Y')
    except Exception as e:
        print(e) 
    return result 

def get_like(i):
    result='get_like'
    try:
        result= driver.find_element_by_xpath(
            f'//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[{i}]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]'
        ).text
    except Exception as e:
        print(e) 
    return result

# %%
#show complete comments in the pfirst page 
#Todo : compete this part for the future use in the loop part 

def get_info(i):
    #try to pen comments
    ful_reviws(i)
    #get comments
    comment=get_comments(i)
    author=get_author(i)
    rating=get_rating(i)
    date=get_date(i)
    likes=get_like(i)

    # print(f"author:{author} rate: {rating} cr_date: {date} likes: {likes}")
    insert(comment,author,rating ,date , likes  )

# %%
i=0
j=1
while i<200:
    j+=1
    i+=1
    try:
        showmore=WebDriverWait(driver, 2).until(
            expected_conditions.presence_of_element_located(
                (By.XPATH,'//div[@class="PFAhAf"]/div[@role="button"]/span[@class="CwaK9"]/span[@class="RveJvd snByac"]')
            )
        )
        showmore.click()
    except Exception as  e:
        pass
    finally:
        time.sleep(1)
        body = driver.find_element_by_css_selector('body')
    
        while j % 50 != 0:
            get_info(j)
            if j % 20 == 0 :
                for zi in range((j//30)+5):
                    body.send_keys(Keys.PAGE_DOWN)
                    time.sleep(.2)

            j+=1
        time.sleep(.5)
# Out:
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[161]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[161]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[161]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[161]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[162]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[162]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[162]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[162]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[163]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[163]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[163]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[163]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[164]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[164]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[164]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[164]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[165]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[165]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[165]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[165]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[166]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[166]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[166]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[166]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[167]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[167]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[167]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[167]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[168]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[168]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[168]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[168]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[169]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[169]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[169]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[169]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[170]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[170]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[170]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[170]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[171]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[171]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[171]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[171]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[172]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[172]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[172]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[172]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[173]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[173]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[173]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[173]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[174]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[174]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[174]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[174]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[175]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[175]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[175]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[175]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[176]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[176]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[176]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[176]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[177]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[177]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[177]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[177]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[178]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[178]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[178]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[178]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[179]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[179]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[179]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[179]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[180]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[180]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[180]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[180]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[181]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[181]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[181]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[181]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[182]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[182]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[182]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[182]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[183]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[183]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[183]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[183]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[184]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[184]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[184]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[184]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[185]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[185]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[185]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[185]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[186]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[186]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[186]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[186]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[187]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[187]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[187]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[187]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[188]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[188]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[188]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[188]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[189]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[189]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[189]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[189]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[190]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[190]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[190]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[190]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[191]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[191]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[191]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[191]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[192]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[192]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[192]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[192]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[193]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[193]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[193]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[193]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[194]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[194]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[194]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[194]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[195]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[195]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[195]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[195]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[196]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[196]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[196]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[196]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[197]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[197]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[197]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[197]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[198]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[198]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[198]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[198]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[199]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[199]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[199]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[199]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[201]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[201]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[201]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[201]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[202]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[202]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[202]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[202]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[203]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[203]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[203]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[203]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[204]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[204]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[204]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[204]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[205]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[205]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[205]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[205]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[206]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[206]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[206]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[206]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[207]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[207]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[207]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[207]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[208]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[208]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[208]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[208]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[209]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[209]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[209]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# ...
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[508]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[508]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[508]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[509]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[509]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[509]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[509]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[510]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[510]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[510]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[510]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[511]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[511]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[511]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[511]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[512]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[512]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[512]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[512]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[513]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[513]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[513]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[513]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[514]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[514]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[514]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[514]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[515]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[515]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[515]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[515]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[516]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[516]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[516]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[516]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[517]/div/div[2]/div[1]/div[1]/span"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[517]/div/div[2]/div[1]/div[1]/div/span[1]/div/div"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[517]/div/div[2]/div[1]/div[1]/div/span[2]"}
#   (Session info: chrome=90.0.4430.212)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="fcxH9b"]/div[4]/c-wiz[2]/div/div[2]/div/div/main/div/div[1]/div[2]/div[1]/div[517]/div/div[2]/div[1]/div[2]/div/div[1]/div[2]"}
#   (Session info: chrome=90.0.4430.212)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-e82a4f4a9670> in <module>
#      18
#      19         while j % 50 != 0:
# ---> 20             get_info(j)
#      21             if j % 10 == 0 :
#      22                 body.send_keys(Keys.PAGE_DOWN)
#
# <ipython-input-13-1a7ab8bb5984> in get_info(i)
#       7     #get comments
#       8     comment=get_comments(i)
# ----> 9     author=get_author(i)
#      10     rating=get_rating(i)
#      11     date=get_date(i)
#
# <ipython-input-12-4ea9e959fdd3> in get_author(i)
#      27     result='get_author'
#      28     try:
# ---> 29         result= driver.find_element_by_xpath(
#      30             f'//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div/div[{i}]/div/div[2]/div[1]/div[1]/span'
#      31         ).text
#
# ~\AppData\Roaming\Python\Python38\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~\AppData\Roaming\Python\Python38\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# ~\AppData\Roaming\Python\Python38\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~\AppData\Roaming\Python\Python38\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~\AppData\Roaming\Python\Python38\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~\AppData\Roaming\Python\Python38\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      76             )
#      77         else:
# ---> 78             return self.request_encode_body(
#      79                 method, url, fields=fields, headers=headers, **urlopen_kw
#      80             )
#
# ~\AppData\Roaming\Python\Python38\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     168         extra_kw.update(urlopen_kw)
#     169
# --> 170         return self.urlopen(method, url, **extra_kw)
#
# ~\AppData\Roaming\Python\Python38\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     373             response = conn.urlopen(method, url, **kw)
#     374         else:
# --> 375             response = conn.urlopen(method, u.request_uri, **kw)
#     376
#     377         redirect_location = redirect and response.get_redirect_location()
#
# ~\AppData\Roaming\Python\Python38\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\AppData\Roaming\Python\Python38\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\AppData\Roaming\Python\Python38\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\AppData\Roaming\Python\Python38\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# C:\Program Files\Python38\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# C:\Program Files\Python38\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# C:\Program Files\Python38\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# C:\Program Files\Python38\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:
